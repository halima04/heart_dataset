# %%
import pandas
import seaborn
import matplotlib.pyplot as plt
pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

csv_data = pandas.read_csv("heart_2020_cleaned.csv")
csv_data.head(25)
# Out:
#    HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0            No  16.60     Yes              No     No             3.0
# 1            No  20.34      No              No    Yes             0.0
# 2            No  26.58     Yes              No     No            20.0
# 3            No  24.21      No              No     No             0.0
# 4            No  23.71      No              No     No            28.0
# 5           Yes  28.87     Yes              No     No             6.0
# 6            No  21.63      No              No     No            15.0
# 7            No  31.64     Yes              No     No             5.0
# 8            No  26.45      No              No     No             0.0
# 9            No  40.69      No              No     No             0.0
# 10          Yes  34.30     Yes              No     No            30.0
# 11           No  28.71     Yes              No     No             0.0
# ...

# %% [markdown]
# As the dataset is too big, I am using a small size of the sample. Otherwise, I will get "nan" over and over again.

# %%
# What is the number of rows and columns in our data?
csv_shape = csv_data.head(25).shape
csv_shape
# Out:
# (25, 18)

# %%
# How would the data be described?
csv_description = csv_data.head(25).describe()
csv_description
# Out:
#              BMI  PhysicalHealth  MentalHealth  SleepTime
# count  25.000000       25.000000     25.000000  25.000000
# mean   26.534400        4.880000      6.880000   7.440000
# std     5.103447        8.809654     12.197404   2.467793
# min    16.600000        0.000000      0.000000   4.000000
# 25%    23.710000        0.000000      0.000000   6.000000
# 50%    26.450000        0.000000      0.000000   7.000000
# 75%    28.900000        5.000000      5.000000   8.000000
# max    40.690000       30.000000     30.000000  15.000000

# %%
# How many of the first 25 respondents have heart disease and smoke?
disease_smoke = csv_data.head(25) [ (csv_data.head(25)["Smoking"].notna()) & (csv_data.head(25)["HeartDisease"] =="Yes") ].shape[0]
disease_smoke
# Out:
# 2

# %%
# How many of the first 25 resondents get between 6 to 8 hours of sleep?
sleep_time = csv_data.head(25) [ (csv_data.head(25) ["SleepTime"] >=6) & (csv_data.head(25) ["SleepTime"] <= 8) ].shape[0]
sleep_time
# Out:
# 14

# %%
# How many of the first 25 respondents have asthma?
have_asthma = csv_data.head(25) [ csv_data.head(25)["Asthma"] =="Yes" ].shape[0]
have_asthma
# Out:
# 5

# %%
# Out of the 25 respondents, how did most of them say their general health status is?
gen_health = csv_data.head(25) 

seaborn.barplot(data = gen_health, x = gen_health.index, y = "GenHealth")
fig = plt.gcf()
fig.set_size_inches(9,6)
plt.title("General Health Responses")
plt.show()

# %%
# What is the correlation between mental and physical health of the first 25 respondents?
mental = csv_data.head(25)["MentalHealth"]
physical = csv_data.head(25)["PhysicalHealth"]

seaborn.scatterplot(x = mental, y = physical)
plt.show()

# %%
# What are all the unique factors in this dataset in BMI level?
unique_heart = csv_data.head(25)["BMI"].unique()
unique_heart
# Out:
# array([16.6 , 20.34, 26.58, 24.21, 23.71, 28.87, 21.63, 31.64, 26.45,
#        40.69, 34.3 , 28.71, 28.37, 28.15, 29.29, 29.18, 26.26, 22.59,
#        29.86, 18.13, 21.16, 28.9 , 26.17, 25.82, 25.75])

# %%
# What will the DataFrame look like if filtered to find all respondents who have kidney disease?
kidney_disease = csv_data.head(25) [ csv_data.head(25) ["KidneyDisease"] == "Yes"]
kidney_disease
# Out:
#    HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 8            No  26.45      No              No     No             0.0
# 18           No  29.86     Yes              No     No             0.0
#
#     MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 8            0.0          No  Female  80 or older  White
# 18           0.0         Yes  Female        75-79  Black
#
#                    Diabetic PhysicalActivity GenHealth  SleepTime Asthma  \
# 8   No, borderline diabetes               No      Fair        5.0     No
# 18                      Yes               No      Fair        5.0     No
#
#    KidneyDisease SkinCancer
# 8            Yes         No
# 18           Yes         No

# %%
# What will the DataFrame look like if filtered to find all respondents who have skin cancer?
skin_cancer = csv_data.head(25) [ csv_data.head(25) ["SkinCancer"] == "Yes"]
skin_cancer
# Out:
#    HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0            No  16.60     Yes              No     No             3.0
# 3            No  24.21      No              No     No             0.0
# 6            No  21.63      No              No     No            15.0
# 19           No  18.13      No              No     No             0.0
# 24           No  25.75      No              No     No             0.0
#
#     MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0           30.0          No  Female        55-59  White      Yes
# 3            0.0          No  Female        75-79  White       No
# 6            0.0          No  Female        70-74  White       No
# 19           0.0          No    Male  80 or older  White       No
# 24           0.0          No  Female  80 or older  White       No
#
#    PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...
